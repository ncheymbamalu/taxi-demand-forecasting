# %% [markdown]
# ### **`Dependencies`**

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings

import plotly.express as px
import polars as pl

from plotly.graph_objects import Figure

from src.config import Paths
from src.utils import transform_data

warnings.filterwarnings("ignore")

# %%
# configure the display options for pl.DataFrame and pl.Series objects
pl.Config(
    tbl_rows=10,
    tbl_cols=100,
    tbl_width_chars=10_000,
    fmt_str_lengths=100,
    fmt_table_cell_list_len=50,
);

# %% [markdown]
# ### **`Data`**

# %%
# %%bash
# cd ..
# dvc pull

# %%
# read in ~/artifacts/data/data.parquet as a pl.DataFrame
df: pl.DataFrame = pl.read_parquet(Paths.DATA)
print(df)

# %%
# plot the houly taxi demand for a few selected locations
fig: Figure = px.line(
    data_frame=df.filter(pl.col("location_id").is_in([43, 142, 230])),
    x="pickup_time",
    y="n_rides",
    color="location_id",
    labels={
        "pickup_time": "Pick-up time (UTC)",
        "n_rides": "Number of taxi rides",
        "location_id": "Location ID"
    },
    markers=True,
    title="NYC Hourly Taxi Demand",
    template="plotly_dark"
)
fig.show()

# %%
# transform the 'df' pl.DataFrame into a pl.DataFrame of features and targets
print(df.pipe(transform_data))

# %%
# %%bash
# cd ..
# make clean
